# %% [markdown]
# # Part 10

# %% [markdown]
# # Visualisation using matplotlib and seaborn
#
# ### matplotlib
#
# <b>matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like wxPython, Qt, or GTK+. There is also a procedural "pylab" interface based on a state machine (like OpenGL), designed to closely resemble that of MATLAB. SciPy makes use of matplotlib.</b>
#
# ### seaborn
#
# <b>Seaborn is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive statistical graphics.</b>

# %% [markdown]
# # Histograms and joint plots

# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats library from scipy
# from scipy import stats

# These are the plotting modules and libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# To make the plots appear in the Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# ## Histogram with <i>matplotlib</i>

# %%
dataset1 = randn(1000)

# %%
plt.hist(dataset1)
# Out:
# (array([  2.,   8.,  42., 105., 216., 233., 212., 117.,  54.,  11.]),
#  array([-3.58922159, -2.93953097, -2.28984035, -1.64014973, -0.99045911,
#         -0.34076849,  0.30892213,  0.95861275,  1.60830337,  2.25799398,
#          2.9076846 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dataset1, color = 'green')
# Out:
# (array([  2.,   8.,  42., 105., 216., 233., 212., 117.,  54.,  11.]),
#  array([-3.58922159, -2.93953097, -2.28984035, -1.64014973, -0.99045911,
#         -0.34076849,  0.30892213,  0.95861275,  1.60830337,  2.25799398,
#          2.9076846 ]),
#  <BarContainer object of 10 artists>)

# %%
dataset2 = randn(800)

# %%
plt.hist(dataset2,bins = 20, color='g')
# Out:
# (array([  1.,   6.,   8.,  21.,  21.,  46.,  56.,  71., 104.,  86., 100.,
#          90.,  70.,  53.,  31.,  19.,   6.,   5.,   5.,   1.]),
#  array([-2.93808677, -2.63166632, -2.32524588, -2.01882543, -1.71240498,
#         -1.40598453, -1.09956408, -0.79314364, -0.48672319, -0.18030274,
#          0.12611771,  0.43253816,  0.7389586 ,  1.04537905,  1.3517995 ,
#          1.65821995,  1.96464039,  2.27106084,  2.57748129,  2.88390174,
#          3.19032219]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ### Plotting both histograms on the same plot
# Plot both in the same notebook cell

# %%
plt.hist(dataset1,color = 'lightblue')
plt.hist(dataset2,color = 'green')
# Out:
# (array([  7.,  29.,  67., 127., 190., 190., 123.,  50.,  11.,   6.]),
#  array([-2.93808677, -2.32524588, -1.71240498, -1.09956408, -0.48672319,
#          0.12611771,  0.7389586 ,  1.3517995 ,  1.96464039,  2.57748129,
#          3.19032219]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Adding some transparency will help
#
# We can add transparency using the parameter <i>alpha</i> which takes values from zero (completely transparent - <i>i.e.</i>invisible!) to one (fully opaque - the default)

# %%
plt.hist(dataset1,density=True, stacked=True,color = 'blue',alpha = 0.2,bins = 10) 
plt.hist(dataset2,density=True, stacked=True,color = 'red',alpha = 0.2,bins = 10)

# Previously we normalise the data by setting normed = True but now we use density=True and stacked=True
# This is so that both can be plotted on the same scale
# Out:
# (array([0.01427777, 0.05915075, 0.13665863, 0.2590395 , 0.38753941,
#         0.38753941, 0.25088078, 0.10198406, 0.02243649, 0.01223809]),
#  array([-2.93808677, -2.32524588, -1.71240498, -1.09956408, -0.48672319,
#          0.12611771,  0.7389586 ,  1.3517995 ,  1.96464039,  2.57748129,
#          3.19032219]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Let's do another example with some more meaningful data

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x1 = df.sepal_length[df.species == "setosa"] 
x2 = df.sepal_length[df.species == "versicolor"]
x3 = df.sepal_length[df.species == "virginica"]

# %%
df.sepal_length[df.species == "versicolor"].count()
# Out:
# 50

# %%
plt.hist(x2,density = False,color = 'green',alpha = 0.3,bins = 10)
# Out:
# (array([ 4.,  1.,  6., 10.,  5.,  8.,  5.,  3.,  5.,  3.]),
#  array([4.9 , 5.11, 5.32, 5.53, 5.74, 5.95, 6.16, 6.37, 6.58, 6.79, 7.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x1,density=True, stacked=True,color = 'red',alpha = 0.5,bins = 20) 
plt.hist(x2,density=True, stacked=True,color = 'green',alpha = 0.3,bins = 10)
plt.hist(x3,density=True, stacked=True,color = 'blue',alpha = 0.5,bins = 20)
# Out:
# (array([0.13333333, 0.        , 0.        , 0.        , 0.13333333,
#         0.53333333, 0.13333333, 0.53333333, 0.26666667, 0.8       ,
#         1.2       , 0.        , 0.93333333, 0.4       , 0.13333333,
#         0.53333333, 0.13333333, 0.        , 0.66666667, 0.13333333]),
#  array([4.9 , 5.05, 5.2 , 5.35, 5.5 , 5.65, 5.8 , 5.95, 6.1 , 6.25, 6.4 ,
#         6.55, 6.7 , 6.85, 7.  , 7.15, 7.3 , 7.45, 7.6 , 7.75, 7.9 ]),
#  <BarContainer object of 20 artists>)

# %%
f, axes = plt.subplots(figsize=(20, 6))
plt.hist(x1,density=True, stacked=True,color = 'red',alpha = 0.5,bins = 20) 
plt.hist(x2,density=True, stacked=True,color = 'green',alpha = 0.3,bins = 20)
plt.hist(x3,density=True, stacked=True,color = 'blue',alpha = 0.5,bins = 20)
# Out:
# (array([0.13333333, 0.        , 0.        , 0.        , 0.13333333,
#         0.53333333, 0.13333333, 0.53333333, 0.26666667, 0.8       ,
#         1.2       , 0.        , 0.93333333, 0.4       , 0.13333333,
#         0.53333333, 0.13333333, 0.        , 0.66666667, 0.13333333]),
#  array([4.9 , 5.05, 5.2 , 5.35, 5.5 , 5.65, 5.8 , 5.95, 6.1 , 6.25, 6.4 ,
#         6.55, 6.7 , 6.85, 7.  , 7.15, 7.3 , 7.45, 7.6 , 7.75, 7.9 ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## Jointplots using <i>seaborn</i>

# %%
data1 = randn(5000)
data2 = randn(5000)

# %%
type(data1)
# Out:
# numpy.ndarray

# %%
sns.jointplot(x=data1,y=data2)

# %% [markdown]
# Same thing, but with some real data

# %%
dframe_wine = pd.read_csv("./data/redwines.csv")

# %%
dframe_wine.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_so2', 'total_so2', 'density', 'pH', 'sulphates',
#        'alcohol', 'quality'],
#       dtype='object')

# %%
d1 = dframe_wine['pH']
d2 = dframe_wine['alcohol']

# %%
sns.jointplot(x=d1,y=d2)

# %% [markdown]
# Another way to show this is by binning the data - we divide the plotting area into hexagons and shade the hexagons according to the number of original data points that would fall within this region
#
# Why hexagons? See <a href = 'https://www.meccanismocomplesso.org/en/hexagonal-binning/'>this article</a>

# %%
sns.jointplot(x=d1,y=d2,kind = 'hex')

# %%
sns.jointplot(x=data1,y=data2,kind = 'hex')

# %% [markdown]
# # Kernel density estimation (KDE) plots

# %%
import webbrowser
url = 'https://en.wikipedia.org/wiki/Kernel_density_estimation'

# %%
webbrowser.open(url)
# Out:
# True

# %% [markdown]
# **Note:** We can also link to the <a href = 'https://en.wikipedia.org/wiki/Kernel_density_estimation'>Wikipedia page</a> directly using HTML, instead of using Python code.
#
# **Another Helpful Video : ** <a href = 'https://www.youtube.com/watch?v=x5zLaWT5KPs'>Intro to KDE</a>
#
# **KDE Playground : ** <a href='https://mathisonian.github.io/kde/'>KDE Visualized</a>

# %%
dataset = randn(25)

# %%
dataset
# Out:
# array([-0.38949336,  1.88551094,  1.40229026, -0.25303107, -0.1461134 ,
#         0.33781908,  1.00388067, -0.60696638,  0.27119128,  0.16830075,
#         0.29869969,  0.07926483, -1.42457852,  0.61505311,  0.97606614,
#        -1.30943708,  0.24106214,  0.48487073,  2.45275179, -1.39209409,
#        -1.38193473, -0.30689623, -2.23999207, -1.05855845, -0.97617141])

# %%
plt.hist(dataset)
# Out:
# (array([1., 4., 2., 2., 4., 6., 3., 1., 1., 1.]),
#  array([-2.23999207, -1.77071769, -1.3014433 , -0.83216892, -0.36289453,
#          0.10637986,  0.57565424,  1.04492863,  1.51420302,  1.9834774 ,
#          2.45275179]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Automatic kernel density estimation using seaborn

# %%
sns.kdeplot(dataset)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Setting the bandwidth manually

# %%
for bw in np.arange(0.5,2,0.25):
    sns.kdeplot(dataset,bw_method = bw,label = bw,lw=1.8)

# %%
x1 = dframe_wine.density

# %%
sns.kdeplot(x1)
# Out:
# <AxesSubplot:xlabel='density', ylabel='Density'>

# %% [markdown]
# Different types of kernels

# %%
import webbrowser
url = 'https://en.wikipedia.org/wiki/Kernel_(statistics)'

# %%
webbrowser.open(url)
# Out:
# True

# %%
kernel_options = ["biw", "cos", "epa", "gau", "tri", "triw"]

# %%
for kern in kernel_options:
    sns.kdeplot(dataset,kernel = kern,label = kern,shade = True,alpha = 0.1,color = 'black')
# Out:
# d:\VSPROJECTS\jupyterenv\lib\site-packages\seaborn\distributions.py:1708: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# d:\VSPROJECTS\jupyterenv\lib\site-packages\seaborn\distributions.py:1708: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# d:\VSPROJECTS\jupyterenv\lib\site-packages\seaborn\distributions.py:1708: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# d:\VSPROJECTS\jupyterenv\lib\site-packages\seaborn\distributions.py:1708: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# d:\VSPROJECTS\jupyterenv\lib\site-packages\seaborn\distributions.py:1708: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# ...

# %%
x3 = dframe_wine.alcohol
for kern in kernel_options:
    sns.kdeplot(x3,kernel = kern,label = kern,shade = True,alpha = 0.1,color = 'black')
# Out:
# d:\VSPROJECTS\jupyterenv\lib\site-packages\seaborn\distributions.py:1708: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# d:\VSPROJECTS\jupyterenv\lib\site-packages\seaborn\distributions.py:1708: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# d:\VSPROJECTS\jupyterenv\lib\site-packages\seaborn\distributions.py:1708: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# d:\VSPROJECTS\jupyterenv\lib\site-packages\seaborn\distributions.py:1708: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# d:\VSPROJECTS\jupyterenv\lib\site-packages\seaborn\distributions.py:1708: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ## Multidimensional KDE plots

# %%
mean = [0,0]
cov = [[1,0],[0,100]]
dataset2 = np.random.multivariate_normal(mean,cov,1000)
dframe = pd.DataFrame(dataset2,columns=['X','Y'])

# %%
dframe.shape
# Out:
# (1000, 2)

# %%
dframe.head()
# Out:
#           X          Y
# 0  1.361042 -11.626014
# 1 -0.330612   1.002782
# 2  2.238534   5.279866
# 3 -2.039005   0.812559
# 4 -0.029352  12.249360

# %%
sns.kdeplot(x=dframe.X,y=dframe.Y) # create multidimensional KDE plot of the data frame
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %%
sns.kdeplot(x=dframe['X'],y=dframe['Y'])
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %% [markdown]
# Add shading

# %%
sns.kdeplot(x=dframe.X,y=dframe.Y,shade = True)
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %%
x1 = dframe_wine.citric_acid
x2 = dframe_wine.pH

# %%
sns.jointplot(x=x1,y=x2)

# %%
sns.kdeplot(x=x1,y=x2,shade = True)
# Out:
# <AxesSubplot:xlabel='citric_acid', ylabel='pH'>

# %%
sns.kdeplot(x=dframe.X, y=dframe.Y,bw_method = 1,shade = True) # manually specify bandwidth
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %%
sns.kdeplot(x=dframe.X,y=dframe.Y,bw_method= 'silverman') # automatically use Silverman's rule of thumb to estimate bw
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %%
sns.jointplot(x='X',y='Y',data=dframe,kind = 'kde') # KDE as a joint plot

# %% [markdown]
# ## Combining plot styles

# %%
dataset = randn(1000)

# %% [markdown]
# * *Distplot function is deprecated and will be removed in a future version. Please adapt your code to use one of two new functions:*
#     * displot(), a figure-level function with a similar flexibility over the kind of plot to draw
#     * histplot(), an axes-level function for plotting histograms, including with kernel density smoothing

# %%
#sns.distplot(dataset,bins = 25)
sns.histplot(dataset,bins = 25,kde=True, stat="density", linewidth=0) # histogram with superimposed KDE plot; default bins for histogram = 10
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#sns.distplot(dataset,bins = 25,rug = False,hist = False)
sns.displot(dataset,rug=False,kind="kde") # other options

# %% [markdown]
# Can set attributes for each of the plots separately by passing dicionaries to `distplot`

# %%
sns.distplot(dataset,bins = 25,
            kde_kws={'color':'indigo','label':'KDE plot','alpha':0.9},
            hist_kws={'color':'orange','label':'Histogram'}
            )
# Out:
# d:\VSPROJECTS\jupyterenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
from pandas import Series

# %%
dataset1 = randn(100)
ser1 = Series(dataset1,name='my_data')
ser1.head()
# Out:
# 0   -1.041311
# 1   -1.414588
# 2    0.304133
# 3    0.371462
# 4    0.348556
# Name: my_data, dtype: float64

# %%
sns.distplot(ser1,bins = 25)
# Out:
# d:\VSPROJECTS\jupyterenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='my_data', ylabel='Density'>

# %% [markdown]
# ## Bar plots
#
# A bar plot is roughly the discrete equivalent of a histogram, and is one of the most commonly used plot types

# %% [markdown]
# Let's create a small (fake) data set

# %%
count = [23, 28, 34, 27, 24]
cities = ('New York', 'London', 'Tokyo', 'New Delhi', 'Sydney')
y_pos = np.arange(len(cities))

# %%
# Create bars
plt.bar(y_pos, count)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# To display the names on the x-axis, we need to add `xticks`

# %%
plt.bar(y_pos, count)
plt.xticks(y_pos, cities)
# Out:
# ([<matplotlib.axis.XTick at 0x212911d0>,
# ...
#  [Text(0, 0, 'New York'),
#   Text(1, 0, 'London'),
#   Text(2, 0, 'Tokyo'),
#   Text(3, 0, 'New Delhi'),
#   Text(4, 0, 'Sydney')])

# %%
plt.bar(y_pos, count, color = 'green')
plt.xticks(y_pos, cities)
# Out:
# ([<matplotlib.axis.XTick at 0x212ccc90>,
# ...
#  [Text(0, 0, 'New York'),
#   Text(1, 0, 'London'),
#   Text(2, 0, 'Tokyo'),
#   Text(3, 0, 'New Delhi'),
#   Text(4, 0, 'Sydney')])

# %%
plt.bar(y_pos, count, color = ['green','blue','red','orange','yellow'])
plt.xticks(y_pos, cities)
# Out:
# ([<matplotlib.axis.XTick at 0x212ac910>,
# ...
#  [Text(0, 0, 'New York'),
#   Text(1, 0, 'London'),
#   Text(2, 0, 'Tokyo'),
#   Text(3, 0, 'New Delhi'),
#   Text(4, 0, 'Sydney')])

# %% [markdown]
# ## Creating several subplots in the same plot

# %% [markdown]
# We can divide the plotting area into subplots using the `subplot()` function (which we used earlier to set the size of the plot).

# %%
df = sns.load_dataset('iris')

# %%
f, axes = plt.subplots(2,2,figsize=(10,8),sharex=False)
sns.distplot( df["sepal_length"] , color="blue", ax = axes[0, 0])
sns.kdeplot(df["sepal_width"] , color="green", ax = axes[0, 1])
sns.kdeplot(df["petal_length"] , color="brown", ax = axes[1, 0])
sns.distplot(df["petal_width"] , color="orange", ax = axes[1, 1])
# Out:
# d:\VSPROJECTS\jupyterenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# d:\VSPROJECTS\jupyterenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal_width', ylabel='Density'>

# %% [markdown]
# # End of part 10
